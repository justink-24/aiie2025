# %% [markdown]
# #**AIIE 2025 Python Review**
#   **Dr. Christelle Scharff | Dr. Kaleema**

# %% [markdown]
# We have used built-in Python libraries.
#
#     As python is opensource there are many libraries available that people have shared on ‘PyPi’, you can use ‘pip install’ to
#     install theses packages.
#
#     When you install Python from Python.org or Anaconda you also install pip, pip is a simple way to download packages at
#     command line from PyPi repository.
#
#
#     A module can contain any Python code we like.
#
#     Programs are designed to be run, whereas modules are designed to be imported and used by programs.
#
#     Syntax : import importable
#
#     In the above syntax ‘importable’ can be a module such as collections, or it can be a Package or a module in a package.
#
#     Example: Import os.path

# %% [markdown]
#     Pandas is an open-source library that provides high performance easy to use data analysis and data manipulation tool.
#
#     It is built on top of NumPy.
#
#     Pandas has built-in visualization features.
#
#     Pandas can work with data from a wide variety of sources.
#
#     To install pandas:
#
#     conda install pandas
#
#     or
#
#     pip install pandas.
#
#
#     [pandas] is derived from the term "panel data", an econometrics term for data sets that include observations over multiple time
#     periods for the same individuals. — Wikipedia

# %% [markdown]
# #Pandas
# https://pandas.pydata.org/

# %% [markdown]
# ##Pandas as series

# %%
import pandas as pd
import numpy as np

# %%
list1 = [100,200,300,400,500,600,700]

# %%
ser1 = pd.Series(list1)

# %%
ser1
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# 5    600
# 6    700
# dtype: int64

# %%
ser1.values
# Out:
# array([100, 200, 300, 400, 500, 600, 700])

# %%
ser1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
ser1[0:4:1]
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
ser2 = pd.Series([800, 900])

# %%
ser3 = ser1+ser2

# %%
#onstructing a series
series1 = pd.Series([0.25,0.55,0.65,1.25,6.58,4.30,8.9])

# %%
series1
# Out:
# 0    0.25
# 1    0.55
# 2    0.65
# 3    1.25
# 4    6.58
# 5    4.30
# 6    8.90
# dtype: float64

# %%
list1 =[1,2,3,4,6,7]
list1[2]
# Out:
# 3

# %%
#constructing a series from list
series2 = pd.Series(list1)
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    6
# 5    7
# dtype: int64

# %%
#Series with explicit index
list2 =[0.25, 0.5, 0.75, 1.0]
ser2 = pd.Series(list2, index=['a','b','c','d'])
ser2
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
ser2.values #To get values from a series
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
ser2.index #to get index from a series
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
series3 = series1+series2
series3
# Out:
# 0     1.25
# 1     2.55
# 2     3.65
# 3     5.25
# 4    12.58
# 5    11.30
# 6      NaN
# dtype: float64

# %%
series3[0] #extracting the values based on index
# Out:
# np.float64(1.25)

# %% [markdown]
# #### Series as specialized dictionary

# %%
population_dict = {'California': 38332521,
'Texas': 26448193,
'New York': 19651127,
'Florida': 19552860,
'Illinois': 12882135}
population_dict
# Out:
# {'California': 38332521,
#  'Texas': 26448193,
#  'New York': 19651127,
#  'Florida': 19552860,
#  'Illinois': 12882135}

# %%
population_newser = pd.Series(population_dict)
population_newser
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
#To access the series
#population['Texas']

# %%
population_newser.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
population_newser.values
# Out:
# array([38332521, 26448193, 19651127, 19552860, 12882135])

# %%
population_newser['New York']
# Out:
# np.int64(19651127)

# %% [markdown]
# ## Pandas as DataFrame

# %% [markdown]
# #### Data Frame Construction

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['I','II','III','IV'])

# %%
df
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#Extract values by column
df['I']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: I, dtype: float64

# %%
#Extract Values by rows
df[['I','II']]
# Out:
#           I        II
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
#Adding new column to the data frame
df['New'] = df['I']+df['II']

# %%
df
# Out:
#           I        II       III        IV       New
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
#Drop the column temporarily
df.drop('New', axis =1)
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           I        II       III        IV       New
# A  2.706850  0.628133  0.907969  0.503826  3.334983
# B  0.651118 -0.319318 -0.848077  0.605965  0.331800
# C -2.018168  0.740122  0.528813 -0.589001 -1.278046
# D  0.188695 -0.758872 -0.933237  0.955057 -0.570177
# E  0.190794  1.978757  2.605967  0.683509  2.169552

# %%
#Drop the column permanently
df.drop('New', axis =1, inplace=True)

# %%
df
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#Drop the row
df.drop('E', axis=0)
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
#Drop the row permanently
df.drop('E', axis=0, inplace=True)

# %%
df
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
#To get the row 'A' data based on row description
df.loc['A']
# Out:
# I      2.706850
# II     0.628133
# III    0.907969
# IV     0.503826
# Name: A, dtype: float64

# %%
#To get the row 'A','B','C' data based on row description
df.loc[['A','B','C']]
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001

# %%
#To get the row 'A' data based on row index
df.iloc[0]
# Out:
# I      2.706850
# II     0.628133
# III    0.907969
# IV     0.503826
# Name: A, dtype: float64

# %%
#To get all the rows data based on row index
df.iloc[2:]
# Out:
#           I        II       III        IV
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
#To extract the data at a particular index of row and column
df.loc['A','II']
# Out:
# np.float64(0.6281327087844596)

# %%
df.iloc[0,1]
# Out:
# np.float64(0.6281327087844596)

# %%
#To get the subset of the data
df.loc[['A','C'],['I','IV']]
# Out:
#           I        IV
# A  2.706850  0.503826
# C -2.018168 -0.589001

# %% [markdown]
# ### Constructing a Data Frame from Series object

# %%
population_dict = {'California': 38332521,'Texas': 26448193,'New York': 19651127,'Florida': 19552860,'Illinois': 12882135}
population_series = pd.Series(population_dict)
population_series
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population_df = pd.DataFrame(population_series, )
population_df
# Out:
#                    0
# California  38332521
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135

# %%
population_dict = {'California': 38332521,'Texas': 26448193,'New York': 19651127,'Florida': 19552860,'Illinois': 12882135}

area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,'Florida': 170312, 'Illinois': 149995}

# %%
states = pd.DataFrame({'population': population_dict,'area': area_dict})
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %% [markdown]
# ### Conditional Selection

# %%
#if you want to know where are values in the daataframe which are >0, it will give the result in boolean


df[df > 0 ]
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057

# %%
df['I'] >0
# Out:
# A     True
# B     True
# C    False
# D     True
# Name: I, dtype: bool

# %%
#Get the resultant values of the data frame whose column 'I' >0
df[df['I'] >0]
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
# To get only column 'I'
df[df['I'] >0]['I']
# Out:
# A    2.706850
# B    0.651118
# D    0.188695
# Name: I, dtype: float64

# %%
df[(df['I']>0) & (df['IV']>0)]
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df[(df['I']>0) | (df['IV']>1)]
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057

# %% [markdown]
# ### Index

# %% [markdown]
# #### Reset Index

# %%
df
# Out:
#           I        II       III        IV
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df.reset_index()
# Out:
#   index         I        II       III        IV
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057

# %% [markdown]
# #### Set Index

# %%
newindex = ['NY','NJ','CA','FL']
newindex
# Out:
# ['NY', 'NJ', 'CA', 'FL']

# %%
df['States'] =newindex
df
# Out:
#           I        II       III        IV States
# A  2.706850  0.628133  0.907969  0.503826     NY
# B  0.651118 -0.319318 -0.848077  0.605965     NJ
# C -2.018168  0.740122  0.528813 -0.589001     CA
# D  0.188695 -0.758872 -0.933237  0.955057     FL

# %%
df.set_index('States')
# Out:
#                I        II       III        IV
# States
# NY      2.706850  0.628133  0.907969  0.503826
# NJ      0.651118 -0.319318 -0.848077  0.605965
# CA     -2.018168  0.740122  0.528813 -0.589001
# FL      0.188695 -0.758872 -0.933237  0.955057

# %% [markdown]
# #### Multi-Index / Hierarchical Index

# %%
outside_ind =['L1','L1','L1','L2','L2','L2']
inside_ind = [1,2,3,1,2,3]
hier_ind = list(zip(outside_ind, inside_ind))
hier_ind = pd.MultiIndex.from_tuples(hier_ind)

# %%
df = pd.DataFrame(randn(6,2), hier_ind, ['A','B'])
df
# Out:
#              A         B
# L1 1  0.302665  1.693723
#    2 -1.706086 -1.159119
#    3 -0.134841  0.390528
# L2 1  0.166905  0.184502
#    2  0.807706  0.072960
#    3  0.638787  0.329646

# %%
df.index.names =['Level','Number']

# %%
df
# Out:
#                      A         B
# Level Number
# L1    1       0.302665  1.693723
#       2      -1.706086 -1.159119
#       3      -0.134841  0.390528
# L2    1       0.166905  0.184502
#       2       0.807706  0.072960
#       3       0.638787  0.329646

# %%
# To extract the data

df.loc['L1'].loc[1]
# Out:
# A    0.302665
# B    1.693723
# Name: 1, dtype: float64

# %%
df.xs('L1')
# Out:
#                A         B
# Number
# 1       0.302665  1.693723
# 2      -1.706086 -1.159119
# 3      -0.134841  0.390528

# %%
df.xs(1,level='Number' )
# Out:
#               A         B
# Level
# L1     0.302665  1.693723
# L2     0.166905  0.184502

# %% [markdown]
# #### Hierarchical Indexing Example : 2

# %%
index = [('California', 2000), ('California', 2010),('California', 2020),
('New York', 2000), ('New York', 2010),('New York', 2020),
('Texas', 2000), ('Texas', 2010), ('Texas', 2020)]

# %%
populations = [33871648, 37253956,37250000,
18976457, 19378102,19378000,
20851820, 25145561, 25145000]

# %%
pop = pd.Series(populations, index=index)
pop
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (California, 2020)    37250000
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (New York, 2020)      19378000
# (Texas, 2000)         20851820
# (Texas, 2010)         25145561
# (Texas, 2020)         25145000
# dtype: int64

# %%
index = pd.MultiIndex.from_tuples(index)
index
# Out:
# MultiIndex([('California', 2000),
#             ('California', 2010),
#             ('California', 2020),
#             (  'New York', 2000),
#             (  'New York', 2010),
#             (  'New York', 2020),
#             (     'Texas', 2000),
#             (     'Texas', 2010),
#             (     'Texas', 2020)],
#            )

# %%
pop = pop.reindex(index)
pop
# Out:
# California  2000    33871648
#             2010    37253956
#             2020    37250000
# New York    2000    18976457
#             2010    19378102
#             2020    19378000
# Texas       2000    20851820
#             2010    25145561
#             2020    25145000
# dtype: int64

# %%
unstacked_pop = pop.unstack()
unstacked_pop
# Out:
#                 2000      2010      2020
# California  33871648  37253956  37250000
# New York    18976457  19378102  19378000
# Texas       20851820  25145561  25145000

# %%
unstacked_pop.stack()
# Out:
# California  2000    33871648
#             2010    37253956
#             2020    37250000
# New York    2000    18976457
#             2010    19378102
#             2020    19378000
# Texas       2000    20851820
#             2010    25145561
#             2020    25145000
# dtype: int64

# %% [markdown]
# ## Missing Data

# %% [markdown]
# #### With Numpy

# %%
import numpy as np

vals2 = np.array([1, np.nan, 3, 4])
vals2.dtype
# Out:
# dtype('float64')

# %%
1 + np.nan
# Out:
# nan

# %%
0 * np.nan
# Out:
# nan

# %%
vals2.sum(), vals2.min(), vals2.max()
# Out:
# (np.float64(nan), np.float64(nan), np.float64(nan))

# %%
np.nansum(vals2), np.nanmin(vals2), np.nanmax(vals2)
# Out:
# (np.float64(8.0), np.float64(1.0), np.float64(4.0))

# %% [markdown]
# #### With Pandas

# %%
#Constructing a DataFrame
data = pd.DataFrame([[1, np.nan, 2],[2, 3, 5],[np.nan, np.nan, 6], [5, np.nan, 6]])
data
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  NaN  6
# 3  5.0  NaN  6

# %%
#dropna() to drop entire row if anyone one value in the row is NaN

df.dropna(axis=0, how='any')
# Out:
#                      A         B
# Level Number
# L1    1       0.302665  1.693723
#       2      -1.706086 -1.159119
#       3      -0.134841  0.390528
# L2    1       0.166905  0.184502
#       2       0.807706  0.072960
#       3       0.638787  0.329646

# %%
#dropna() to drop entire column if anyone one value in the row is NaN

df.dropna(axis=1, how='any')
# Out:
#                      A         B
# Level Number
# L1    1       0.302665  1.693723
#       2      -1.706086 -1.159119
#       3      -0.134841  0.390528
# L2    1       0.166905  0.184502
#       2       0.807706  0.072960
#       3       0.638787  0.329646

# %%
#dropna() to drop entire row if all the values in the row are NaN

df.dropna(axis = 0, how='all')
# Out:
#                      A         B
# Level Number
# L1    1       0.302665  1.693723
#       2      -1.706086 -1.159119
#       3      -0.134841  0.390528
# L2    1       0.166905  0.184502
#       2       0.807706  0.072960
#       3       0.638787  0.329646

# %%
#dropna() to drop entire column if all the values in the column are NaN
df.dropna(axis = 1, how='all')
# Out:
#                      A         B
# Level Number
# L1    1       0.302665  1.693723
#       2      -1.706086 -1.159119
#       3      -0.134841  0.390528
# L2    1       0.166905  0.184502
#       2       0.807706  0.072960
#       3       0.638787  0.329646

# %%
#dropna() to drop entire column if any of the values in the column are NaN
df.dropna(axis='columns')
# Out:
#                      A         B
# Level Number
# L1    1       0.302665  1.693723
#       2      -1.706086 -1.159119
#       3      -0.134841  0.390528
# L2    1       0.166905  0.184502
#       2       0.807706  0.072960
#       3       0.638787  0.329646

# %%
#dropna() with thersold =2 value, if there are two or more then it will drop the row/column
df.dropna(thresh=2)
# Out:
#                      A         B
# Level Number
# L1    1       0.302665  1.693723
#       2      -1.706086 -1.159119
#       3      -0.134841  0.390528
# L2    1       0.166905  0.184502
#       2       0.807706  0.072960
#       3       0.638787  0.329646

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %%
# forward-fill
data.fillna(method='ffill')
# Out:
# <ipython-input-93-c47b1cefb12a>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %%
# back-fill
data.fillna(method='bfill')
# Out:
# <ipython-input-94-7b95ada8f1ff>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %%
# fill-value
data.fillna(value='N/A')
# Out:
# a    1.0
# b    N/A
# c    2.0
# d    N/A
# e    3.0
# dtype: object

# %%
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data = pd.DataFrame([[1, np.nan, 2],[2, 3, 5],[np.nan, np.nan, 6], [5, np.nan, 6]])
data
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  NaN  6
# 3  5.0  NaN  6

# %%
data.fillna(value=data.mean())
# Out:
#           0    1  2
# 0  1.000000  3.0  2
# 1  2.000000  3.0  5
# 2  2.666667  3.0  6
# 3  5.000000  3.0  6

# %% [markdown]
# ### Groupby

# %%
data = {'Department':['Sales','Finanace','Finanace','HR','HR','Marketing','IT','IT'],
        'Employess':['Sam','Alexia','Krish','Amy','Frank','Charles','Christlle','Ben'],
        'Salary(in Thousands)':[200,350,1850,450,560,800,950,850]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Department  Employess  Salary(in Thousands)
# 0      Sales        Sam                   200
# 1   Finanace     Alexia                   350
# 2   Finanace      Krish                  1850
# 3         HR        Amy                   450
# 4         HR      Frank                   560
# 5  Marketing    Charles                   800
# 6         IT  Christlle                   950
# 7         IT        Ben                   850

# %%
dept = df.groupby('Department').mean()
dept
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
dept = df.groupby('Department').describe()
dept

# %%
dept = df.groupby('Department').describe()
dept

# %% [markdown]
# #Combining Datasets: Concat and Append

# %%
ser1 = pd.Series(['A', 'B', 'C'], index=[1, 2, 3])
ser2 = pd.Series(['D', 'E', 'F'], index=['a','b','c'])
df1 = pd.DataFrame(ser1)
df2 = pd.DataFrame(ser2)

# %%
df1

# %%
df2

# %%
pd.concat([df1, df2])

# %%
pd.concat([df1, df2], axis=1)

# %%
df1.append(df2)

# %%
def make_df(cols, ind):
 data = {c: [str(c) + str(i) for i in ind] for c in cols}
 return pd.DataFrame(data, ind)

# %%
df1 = make_df('AB', [1, 2])
df2 = make_df('AB', [3, 4])
print(df1); print(df2);
print(pd.concat([df1, df2]));
print(pd.concat([df1, df2], axis =1));

# %%
print(pd.concat([df1, df2], axis =1, ignore_index=True));

# %%
print(pd.concat([df1, df2], keys=['x', 'y']));

# %%
print(pd.concat([df1, df2], join='inner'));

# %%
print(df1.append(df2))

# %% [markdown]
# # Combining Datasets: Merge and Join

# %% [markdown]
# One-to-one joins

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],'hire_date': [2004, 2008, 2012, 2014]})

# %%
#df5 = pd.concat(df1,df2)

# %%
df3 = pd.merge(df1, df2, on='employee')
df3

# %% [markdown]
# Many-to-one joins

# %%
df4 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],'supervisor': ['Carly', 'Guido', 'Steve']})

# %%
df5 = pd.merge(df3, df4)
df5

# %% [markdown]
# Many-to-many joins

# %%
df6 = pd.DataFrame({'group': ['Accounting', 'Accounting',
'Engineering', 'Engineering', 'HR', 'HR'],'skills': ['math', 'spreadsheets', 'coding', 'linux',
'spreadsheets', 'organization']})

# %%
print(pd.merge(df1, df6))

# %% [markdown]
# Specification of the Merge Key

# %%
print(pd.merge(df1, df2, on='employee'))

# %%
print(pd.merge(df1, df3, left_on="employee", right_on="group"))

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2'])

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)

# %%
left.join(right, how='outer')

# %% [markdown]
# ### Operations on Data Frames

# %%
df = pd.read_csv('example')
df

# %%
df.to_csv('example',index=False)

# %%
df['col2'].unique()

# %%
df['col2'].nunique()

# %%
df['col2'].value_counts()

# %% [markdown]
# ## Pivot Tables

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)
df

# %%
df.pivot_table(values='D',index=['A', 'B'],columns=['C'])

# %%
df = pd.read_csv('/content/titanic-train.csv')

# %%
df.head(10)

# %%
df.pivot_table(index='total_bedrooms',
               columns='median_income',
               values='median_house_value',
               aggfunc='min')

# %% [markdown]
# ## Correlations
# In Pandas you can also calculate corelations between features. Which will help to find redudant information.

# %%
df['IsFemale'] = df['Sex'] == 'female'

# %%
df.plot()

# %%
correlated_with_survived = df.corr()['Survived'].sort_values()
correlated_with_survived

# %% [markdown]
# ## The Pandas Index Object

# %%
ind = pd.Index([[[2, 3, 7],[7, 5, 11]],[[8,6,5],[9,4,3]]])
ind

# %%
print(ind.size, ind.shape, ind.ndim, ind.dtype)

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

# %%
indA & indB # intersection

# %%
indA | indB # union

# %%
indA ^ indB # symmetric difference

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
'New York': 141297, 'Florida': 170312,
'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
'New York': 19651127, 'Florida': 19552860,
'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data

# %%
data['density'] = data['pop'] / data['area']
data

# %%
data.T

# %%
data.iloc[:3, :2]

# %%
data.loc[:'Illinois', :'pop']

# %%
#data.ix[:3, :'pop']

# %% [markdown]
# ### Data Indexing and Selection

# %% [markdown]
# #### Data Selection in Series

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0],
index=['a', 'b', 'c', 'd'])
data

# %%
'0.25' in data

# %%
data.keys()

# %%
data['e'] = 1.25

# %%
data.keys()

# %%
data.values

# %%
# slicing by explicit index
data['a':'c']

# %%
# slicing by implicit integer index
data[0:2]

# %%
# masking
data[(data > 0.3) & (data < 0.8)]

# %% [markdown]
# ### Operating on Data in Pandas

# %%
import pandas as pd
import numpy as np

# %%
rng = np.random.RandomState(42)
ser = pd.Series(rng.randint(0, 100, 8))
ser

# %%
np.exp(ser)

# %%
df = pd.DataFrame(rng.randint(0, 10, (3, 4)),
columns=['A', 'B', 'C', 'D'])
df

# %%
np.sin(df * np.pi / 4)

# %% [markdown]
# ### Dataframe from a CSV File

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()

# %%
HousingDF=pd.read_csv('/content/housing.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-103-39a0ced2edad> in <cell line: 0>()
# ----> 1 HousingDF=pd.read_csv('/content/housing.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
HousingDF.head(10)

# %%
HousingDF.describe()

# %%
HousingDF.shape

# %%
HousingDF.dtypes

# %%
HousingDF.info()

# %%
HousingDF[HousingDF.notnull()]

# %%
HousingDF.notnull()

# %%
print(HousingDF.isnull().values.any()) #To check if there any missing values

# %%
print(HousingDF.isnull().sum().sum()) #To know how many null values

# %%
print(HousingDF.isnull().sum())

# %%
HousingDF1 = HousingDF.copy()
HousingDF1.dropna()
HousingDF1.info()

# %%
HousingDF1.iloc[:7, :4]

# %%
HousingDF1.loc[:10, :'population']

# %%
HousingDF1['Median_Age>50'] = HousingDF1['housing_median_age'] >50
HousingDF1.head()

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/students_data.csv')
df.head(10)
# Out:
#    StudentID     Name  Gender  Grade  Attendance           Subject
# 0        1.0  Charlie    Male   69.0         NaN           English
# 1        2.0    Frank       M   55.0        71.0           Physics
# 2        3.0  Charlie    Male   75.0        97.0              Math
# 3        4.0    Alice    male   46.0        59.0           Biology
# 4        5.0     Noah    Male   47.0        86.0              Math
# 5        6.0    Alice       F   87.0        70.0           Biology
# 6        7.0    Karen  female   71.0        61.0           Physics
# 7        8.0    Frank    male   82.0        95.0           Physics
# 8        9.0      Bob    Male   82.0        52.0           English
# 9       10.0    Henry       M   56.0        86.0  Computer Science

# %%
#part 1
df.describe()
df.shape
df.dtypes
df.info()
df.describe()
df[df.notnull()]
df.notnull()
print(df.isnull().values.any()) #To check if there any missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   968 non-null    float64
#  1   Name        982 non-null    object
#  2   Gender      1000 non-null   object
#  3   Grade       955 non-null    float64
#  4   Attendance  948 non-null    float64
#  5   Subject     1000 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 47.0+ KB
# True

# %%
#part 2
df['Grade'] = df['Grade'].fillna(df['Grade'].mean())
df['Attendance'] = df['Attendance'].fillna(0)
df = df.dropna(subset=['Name', 'StudentID'])
df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female'})
df['Gender'] = df['Gender'].str.capitalize()
df.head(10)
# Out:
# <ipython-input-3-20dfc2e53436>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female'})
# <ipython-input-3-20dfc2e53436>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].str.capitalize()
#    StudentID     Name  Gender  Grade  Attendance           Subject
# 0        1.0  Charlie    Male   69.0         0.0           English
# 1        2.0    Frank    Male   55.0        71.0           Physics
# ...

# %%
#part3
df['Pass/Fail'] = df['Grade'].apply(lambda x: 'Pass' if x >= 50 else 'Fail')
attendance_df = df[df['Attendance'] > 75]
sorted_df = attendance_df.sort_values(by='Grade', ascending=False)
df.head(10)
# Out:
#    StudentID     Name  Gender  Grade  Attendance           Subject Pass/Fail
# 0        1.0  Charlie    Male   69.0         0.0           English      Pass
# 1        2.0    Frank    Male   55.0        71.0           Physics      Pass
# 2        3.0  Charlie    Male   75.0        97.0              Math      Pass
# 3        4.0    Alice    Male   46.0        59.0           Biology      Fail
# 4        5.0     Noah    Male   47.0        86.0              Math      Fail
# 5        6.0    Alice  Female   87.0        70.0           Biology      Pass
# 6        7.0    Karen  Female   71.0        61.0           Physics      Pass
# 7        8.0    Frank    Male   82.0        95.0           Physics      Pass
# 8        9.0      Bob    Male   82.0        52.0           English      Pass
# 9       10.0    Henry    Male   56.0        86.0  Computer Science      Pass

# %%
#part4
avg_grade_by_subject = df.groupby('Subject')['Grade'].mean().reset_index()
print(avg_grade_by_subject)
top_3_by_subject = df.sort_values(by='Grade', ascending=False).groupby('Subject').head(3)
print(top_3_by_subject)
pivot_table = pd.pivot_table(df, values='Grade', index='Subject', columns='Gender', aggfunc='mean')
print(pivot_table)
# Out:
#             Subject      Grade
# 0           Biology  64.859448
# 1         Chemistry  67.698038
# 2  Computer Science  64.568805
# 3           English  65.432019
# 4           History  65.031339
# 5              Math  65.340708
# 6           Physics  66.223491
# 7           Science  65.190358
#      StudentID     Name  Gender  Grade  Attendance           Subject Pass/Fail
# 36        37.0   Olivia    Male  108.0        59.0           Physics      Pass
# 926      927.0  Charlie  Female  107.0        72.0         Chemistry      Pass
# 198      199.0     Jack    Male  107.0         0.0              Math      Pass
# 715      716.0     Noah    Male  107.0        97.0              Math      Pass
# 844      845.0      Bob    Male  106.0        54.0           English      Pass
# 275      276.0      Mia    Male  103.0        78.0           Physics      Pass
# 274      275.0     Jack    Male  103.0        63.0           Science      Pass
# ...
